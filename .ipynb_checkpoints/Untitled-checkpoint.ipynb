# %%
import pandas as pd

weather=pd.read_csv("jfk.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 2023-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  10.29
# 2023-02-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  25.72
# 2023-02-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  17.00
# 2023-02-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  12.30
# 2023-02-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN    NaN
#
#             FMTM  PGTM  PRCP  SNOW  SNWD  ...  WT13  WT14  WT15  WT16  WT17  \
# DATE                                      ...
# 1970-01-01   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   NaN   NaN  0.02   0.0   0.0  ...   NaN   NaN   NaN   1.0   NaN
# 1970-01-04   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-05   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...
# 2023-02-02   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2023-02-03   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2023-02-04   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2023-02-05   NaN  52.0  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2023-02-06   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
#
#             WT18  WT19  WT21  WT22  WV01
# DATE
# 1970-01-01   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   1.0   NaN   NaN   NaN   NaN
# 1970-01-04   1.0   NaN   NaN   NaN   NaN
# 1970-01-05   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...
# 2023-02-02   NaN   NaN   NaN   NaN   NaN
# 2023-02-03   NaN   NaN   NaN   NaN   NaN
# 2023-02-04   NaN   NaN   NaN   NaN   NaN
# 2023-02-05   NaN   NaN   NaN   NaN   NaN
# 2023-02-06   NaN   NaN   NaN   NaN   NaN
#
# [19395 rows x 45 columns]

# %%
null_pct=weather.apply(pd.isnull).sum()/weather.shape[0]
 
# above variable stores the percentage of null values in each col

# %%
weather.apply(pd.isnull).sum()
#the below shows the number of null values in each column
# Out:
# STATION        0
# NAME           0
# ACMH        9780
# ACSH        9779
# AWND        5117
# FMTM        9271
# PGTM        7125
# PRCP           1
# SNOW           1
# SNWD           2
# TAVG       13123
# TMAX           1
# TMIN           1
# TSUN       19364
# WDF1        9784
# WDF2        9619
# WDF5        9702
# WDFG       14274
# WDFM       19394
# WESD       13324
# WSF1        9781
# WSF2        9619
# WSF5        9703
# WSFG       11932
# WSFM       19394
# WT01       12221
# WT02       18133
# WT03       18106
# WT04       19058
# WT05       19031
# WT06       19214
# WT07       19287
# WT08       15474
# WT09       19255
# WT11       19381
# WT13       17210
# WT14       18508
# WT15       19353
# WT16       12818
# WT17       19335
# WT18       18228
# WT19       19394
# WT21       19390
# WT22       19346
# WV01       19394
# dtype: int64

# %%
null_pct
#the below show the percentage of null values in each coloumn
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.504254
# ACSH       0.504202
# AWND       0.263831
# FMTM       0.478010
# PGTM       0.367363
# PRCP       0.000052
# SNOW       0.000052
# SNWD       0.000103
# TAVG       0.676618
# TMAX       0.000052
# TMIN       0.000052
# TSUN       0.998402
# WDF1       0.504460
# WDF2       0.495953
# WDF5       0.500232
# WDFG       0.735963
# WDFM       0.999948
# WESD       0.686981
# WSF1       0.504305
# WSF2       0.495953
# WSF5       0.500284
# WSFG       0.615210
# WSFM       0.999948
# WT01       0.630111
# WT02       0.934932
# WT03       0.933540
# WT04       0.982624
# WT05       0.981232
# WT06       0.990668
# WT07       0.994432
# WT08       0.797834
# WT09       0.992782
# WT11       0.999278
# WT13       0.887342
# WT14       0.954267
# WT15       0.997834
# WT16       0.660892
# WT17       0.996906
# WT18       0.939830
# WT19       0.999948
# WT21       0.999742
# WT22       0.997474
# WV01       0.999948
# dtype: float64

# %%
valid_columns=weather.columns[null_pct<0.5]

#valid_columns only stores the coloumn where the null values are less the 5%

# %%
valid_columns
#the below coloums are the columns those have null values less than 5%
# Out:
# Index(['STATION', 'NAME', 'AWND', 'FMTM', 'PGTM', 'PRCP', 'SNOW', 'SNWD',
#        'TMAX', 'TMIN', 'WDF2', 'WSF2'],
#       dtype='object')

# %%
weather=weather[valid_columns].copy()
#In the data only valid_columns(<5%) are stored and rest of the others are discarded

# %%
weather.columns=weather.columns.str.lower()
#lowercase the coloumn

# %%
weather
# Out:
#                 station                              name   awnd  fmtm  pgtm  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN   NaN   NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN   NaN   NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN   NaN   NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN   NaN   NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN   NaN   NaN
# ...                 ...                               ...    ...   ...   ...
# 2023-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.29   NaN   NaN
# 2023-02-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  25.72   NaN   NaN
# 2023-02-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  17.00   NaN   NaN
# 2023-02-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  12.30   NaN  52.0
# 2023-02-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN   NaN   NaN
#
#             prcp  snow  snwd  tmax  tmin   wdf2  wsf2
# DATE
# 1970-01-01  0.00   0.0   0.0  28.0  22.0    NaN   NaN
# 1970-01-02  0.00   0.0   0.0  31.0  22.0    NaN   NaN
# 1970-01-03  0.02   0.0   0.0  38.0  25.0    NaN   NaN
# 1970-01-04  0.00   0.0   0.0  31.0  23.0    NaN   NaN
# 1970-01-05  0.00   0.0   0.0  35.0  21.0    NaN   NaN
# ...          ...   ...   ...   ...   ...    ...   ...
# 2023-02-02  0.00   0.0   0.0  39.0  24.0  230.0  23.0
# 2023-02-03  0.00   0.0   0.0  35.0  11.0  310.0  42.9
# 2023-02-04  0.00   0.0   0.0  27.0   4.0  320.0  36.9
# 2023-02-05  0.00   0.0   0.0  44.0  27.0  210.0  25.1
# 2023-02-06   NaN   NaN   NaN   NaN   NaN    NaN   NaN
#
# [19395 rows x 12 columns]

# %%
weather=weather.ffill()
#check the previous value and fill the next null value with previous value

# %%
weather.apply(pd.isnull).sum()
# Out:
# station       0
# name          0
# awnd       5113
# fmtm       5113
# pgtm       2069
# prcp          0
# snow          0
# snwd          0
# tmax          0
# tmin          0
# wdf2       9617
# wsf2       9617
# dtype: int64

# %%
weather
# Out:
#                 station                              name   awnd    fmtm  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN     NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN     NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN     NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN     NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN     NaN
# ...                 ...                               ...    ...     ...
# 2023-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.29  1715.0
# 2023-02-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  25.72  1715.0
# 2023-02-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  17.00  1715.0
# 2023-02-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  12.30  1715.0
# 2023-02-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  12.30  1715.0
#
#               pgtm  prcp  snow  snwd  tmax  tmin   wdf2  wsf2
# DATE
# 1970-01-01     NaN  0.00   0.0   0.0  28.0  22.0    NaN   NaN
# 1970-01-02     NaN  0.00   0.0   0.0  31.0  22.0    NaN   NaN
# 1970-01-03     NaN  0.02   0.0   0.0  38.0  25.0    NaN   NaN
# 1970-01-04     NaN  0.00   0.0   0.0  31.0  23.0    NaN   NaN
# 1970-01-05     NaN  0.00   0.0   0.0  35.0  21.0    NaN   NaN
# ...            ...   ...   ...   ...   ...   ...    ...   ...
# 2023-02-02  2215.0  0.00   0.0   0.0  39.0  24.0  230.0  23.0
# 2023-02-03  2215.0  0.00   0.0   0.0  35.0  11.0  310.0  42.9
# 2023-02-04  2215.0  0.00   0.0   0.0  27.0   4.0  320.0  36.9
# 2023-02-05    52.0  0.00   0.0   0.0  44.0  27.0  210.0  25.1
# 2023-02-06    52.0  0.00   0.0   0.0  44.0  27.0  210.0  25.1
#
# [19395 rows x 12 columns]

# %%
weather = weather.drop('awnd', axis=1)
#drop the col(1) row(0)

# %%
weather
# Out:
#                 station                              name    fmtm    pgtm  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US     NaN     NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US     NaN     NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US     NaN     NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US     NaN     NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US     NaN     NaN
# ...                 ...                               ...     ...     ...
# 2023-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1715.0  2215.0
# 2023-02-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1715.0  2215.0
# 2023-02-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1715.0  2215.0
# 2023-02-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1715.0    52.0
# 2023-02-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1715.0    52.0
#
#             prcp  snow  snwd  tmax  tmin   wdf2  wsf2
# DATE
# 1970-01-01  0.00   0.0   0.0  28.0  22.0    NaN   NaN
# 1970-01-02  0.00   0.0   0.0  31.0  22.0    NaN   NaN
# 1970-01-03  0.02   0.0   0.0  38.0  25.0    NaN   NaN
# 1970-01-04  0.00   0.0   0.0  31.0  23.0    NaN   NaN
# 1970-01-05  0.00   0.0   0.0  35.0  21.0    NaN   NaN
# ...          ...   ...   ...   ...   ...    ...   ...
# 2023-02-02  0.00   0.0   0.0  39.0  24.0  230.0  23.0
# 2023-02-03  0.00   0.0   0.0  35.0  11.0  310.0  42.9
# 2023-02-04  0.00   0.0   0.0  27.0   4.0  320.0  36.9
# 2023-02-05  0.00   0.0   0.0  44.0  27.0  210.0  25.1
# 2023-02-06  0.00   0.0   0.0  44.0  27.0  210.0  25.1
#
# [19395 rows x 11 columns]

# %%
weather = weather.drop('fmtm', axis=1)

# %%
weather
# Out:
#                 station                              name    pgtm  prcp  snow  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US     NaN  0.00   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US     NaN  0.00   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US     NaN  0.02   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US     NaN  0.00   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US     NaN  0.00   0.0
# ...                 ...                               ...     ...   ...   ...
# 2023-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2215.0  0.00   0.0
# 2023-02-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2215.0  0.00   0.0
# 2023-02-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2215.0  0.00   0.0
# 2023-02-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    52.0  0.00   0.0
# 2023-02-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    52.0  0.00   0.0
#
#             snwd  tmax  tmin   wdf2  wsf2
# DATE
# 1970-01-01   0.0  28.0  22.0    NaN   NaN
# 1970-01-02   0.0  31.0  22.0    NaN   NaN
# 1970-01-03   0.0  38.0  25.0    NaN   NaN
# 1970-01-04   0.0  31.0  23.0    NaN   NaN
# 1970-01-05   0.0  35.0  21.0    NaN   NaN
# ...          ...   ...   ...    ...   ...
# 2023-02-02   0.0  39.0  24.0  230.0  23.0
# 2023-02-03   0.0  35.0  11.0  310.0  42.9
# 2023-02-04   0.0  27.0   4.0  320.0  36.9
# 2023-02-05   0.0  44.0  27.0  210.0  25.1
# 2023-02-06   0.0  44.0  27.0  210.0  25.1
#
# [19395 rows x 10 columns]

# %%
weather = weather.drop('pgtm', axis=1)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin   wdf2  wsf2
# DATE
# 1970-01-01  28.0  22.0    NaN   NaN
# 1970-01-02  31.0  22.0    NaN   NaN
# 1970-01-03  38.0  25.0    NaN   NaN
# 1970-01-04  31.0  23.0    NaN   NaN
# 1970-01-05  35.0  21.0    NaN   NaN
# ...          ...   ...    ...   ...
# 2023-02-02  39.0  24.0  230.0  23.0
# 2023-02-03  35.0  11.0  310.0  42.9
# 2023-02-04  27.0   4.0  320.0  36.9
# 2023-02-05  44.0  27.0  210.0  25.1
# 2023-02-06  44.0  27.0  210.0  25.1
#
# [19395 rows x 9 columns]

# %%
weather = weather.drop('wdf2', axis=1)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  wsf2
# DATE
# 1970-01-01  28.0  22.0   NaN
# 1970-01-02  31.0  22.0   NaN
# 1970-01-03  38.0  25.0   NaN
# 1970-01-04  31.0  23.0   NaN
# 1970-01-05  35.0  21.0   NaN
# ...          ...   ...   ...
# 2023-02-02  39.0  24.0  23.0
# 2023-02-03  35.0  11.0  42.9
# 2023-02-04  27.0   4.0  36.9
# 2023-02-05  44.0  27.0  25.1
# 2023-02-06  44.0  27.0  25.1
#
# [19395 rows x 8 columns]

# %%
weather = weather.drop('wsf2', axis=1)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin
# DATE
# 1970-01-01  28.0  22.0
# 1970-01-02  31.0  22.0
# 1970-01-03  38.0  25.0
# 1970-01-04  31.0  23.0
# 1970-01-05  35.0  21.0
# ...          ...   ...
# 2023-02-02  39.0  24.0
# 2023-02-03  35.0  11.0
# 2023-02-04  27.0   4.0
# 2023-02-05  44.0  27.0
# 2023-02-06  44.0  27.0
#
# [19395 rows x 7 columns]

# %%
weather.apply(pd.isnull).sum()
#No coloumn have null value
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax       float64
# tmin       float64
# dtype: object

# %%
weather.dtypes
#data type of each columns
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax       float64
# tmin       float64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2023-01-28', '2023-01-29', '2023-01-30', '2023-01-31', '2023-02-01',
#        '2023-02-02', '2023-02-03', '2023-02-04', '2023-02-05', '2023-02-06'],
#       dtype='object', name='DATE', length=19395)

# %%
weather.index=pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2023-01-28', '2023-01-29', '2023-01-30', '2023-01-31',
#                '2023-02-01', '2023-02-02', '2023-02-03', '2023-02-04',
#                '2023-02-05', '2023-02-06'],
#               dtype='datetime64[ns]', name='DATE', length=19395, freq=None)

# %%
weather.index.year.value_counts().sort_index()
#show the numbers of record from each year
# Out:
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023     37
# Name: DATE, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <AxesSubplot: xlabel='DATE'>

# %%
weather["prcp"].plot()
# Out:
# <AxesSubplot: xlabel='DATE'>

# %%
weather["target"]=weather.shift(-1)["tmax"]
#this will make another column(target) which will store the max temp of the next day

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01  28.0  22.0    31.0
# 1970-01-02  31.0  22.0    38.0
# 1970-01-03  38.0  25.0    31.0
# 1970-01-04  31.0  23.0    35.0
# 1970-01-05  35.0  21.0    36.0
# ...          ...   ...     ...
# 2023-02-02  39.0  24.0    35.0
# 2023-02-03  35.0  11.0    27.0
# 2023-02-04  27.0   4.0    44.0
# 2023-02-05  44.0  27.0    44.0
# 2023-02-06  44.0  27.0     NaN
#
# [19395 rows x 8 columns]

# %%
weather=weather.ffill()
#for the last row

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01  28.0  22.0    31.0
# 1970-01-02  31.0  22.0    38.0
# 1970-01-03  38.0  25.0    31.0
# 1970-01-04  31.0  23.0    35.0
# 1970-01-05  35.0  21.0    36.0
# ...          ...   ...     ...
# 2023-02-02  39.0  24.0    35.0
# 2023-02-03  35.0  11.0    27.0
# 2023-02-04  27.0   4.0    44.0
# 2023-02-05  44.0  27.0    44.0
# 2023-02-06  44.0  27.0    44.0
#
# [19395 rows x 8 columns]

# %%
weather.corr() #this shows the corellation between diff variables
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7288\1969925047.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   weather.corr() #this shows the corellation between diff variables
#             prcp      snow      snwd      tmax      tmin    target
# prcp    1.000000  0.150940  0.001246 -0.006765  0.052569 -0.002945
# snow    0.150940  1.000000  0.232638 -0.174296 -0.158523 -0.171950
# snwd    0.001246  0.232638  1.000000 -0.258638 -0.255736 -0.239864
# tmax   -0.006765 -0.174296 -0.258638  1.000000  0.955343  0.915117
# tmin    0.052569 -0.158523 -0.255736  0.955343  1.000000  0.915326
# target -0.002945 -0.171950 -0.239864  0.915117  0.915326  1.000000

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %% [markdown]
# # Linear regression

# %%
from sklearn.linear_model import LinearRegression

lir=LinearRegression()

# %%
def backtest1(weather, model, predictors, start=3650, step=90): #time series cross validation
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]#from starting till i'th days 
        test = weather.iloc[i:(i+step),:]#from i'th till (i+step)days
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions=backtest1(weather,lir,predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229396   7.229396
# 1979-12-31    42.0   43.673846   1.673846
# 1980-01-01    41.0   41.579185   0.579185
# 1980-01-02    36.0   43.961961   7.961961
# 1980-01-03    30.0   40.204809  10.204809
# ...            ...         ...        ...
# 2023-02-02    35.0   39.599181   4.599181
# 2023-02-03    27.0   31.088002   4.088002
# 2023-02-04    44.0   23.887604  20.112396
# 2023-02-05    44.0   43.388630   0.611370
# 2023-02-06    44.0   43.388630   0.611370
#
# [15745 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error # model evaluation by finding the mean absolute error

#linear regression

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 5.142744686619332

# %% [markdown]
# # RIDGE REGRESSION

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=.1)

# %%
predictors
#these are columns from which predictions will bw done
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
def backtest2(weather, model, predictors, start=3650, step=90): #time series cross validation
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]#from starting till i'th days 
        test = weather.iloc[i:(i+step),:]#from i'th till (i+step)days
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions2=backtest2(weather,rr,predictors)

# %%
predictions2 #model evaluation (evaluating the accuracy of the model)
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 2023-02-02    35.0   39.599176   4.599176
# 2023-02-03    27.0   31.088006   4.088006
# 2023-02-04    44.0   23.887607  20.112393
# 2023-02-05    44.0   43.388627   0.611373
# 2023-02-06    44.0   43.388627   0.611373
#
# [15745 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error # model evaluation by finding the mean absolute error

#ridge regression

mean_absolute_error(predictions2["actual"], predictions2["prediction"])

#this find the mean absolute error(just finding the average of the diff column)
# Out:
# 5.142743334902253

# %% [markdown]
# # LASSO REGRESSION

# %%
from sklearn.linear_model import Lasso
lr=Lasso(alpha=.1)
#lasso regration

# %%
def backtest3(weather, model, predictors, start=3650, step=90): #time series cross validation
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]#from starting till i'th days 
        test = weather.iloc[i:(i+step),:]#from i'th till (i+step)days
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions3=backtest3(weather,lr,predictors)

# for lasso regression calling tscv function

# %%
predictions3
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.034510   7.034510
# 1979-12-31    42.0   43.511192   1.511192
# 1980-01-01    41.0   41.440884   0.440884
# 1980-01-02    36.0   43.745685   7.745685
# 1980-01-03    30.0   39.956809   9.956809
# ...            ...         ...        ...
# 2023-02-02    35.0   39.526830   4.526830
# 2023-02-03    27.0   31.146220   4.146220
# 2023-02-04    44.0   23.941191  20.058809
# 2023-02-05    44.0   43.338407   0.661593
# 2023-02-06    44.0   43.338407   0.661593
#
# [15745 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error # model evaluation by finding the mean absolute error

#(for lasso regression)

mean_absolute_error(predictions3["actual"], predictions3["prediction"])
# Out:
# 5.1432023950190855

# %%
predictions.sort_values("diff", ascending=False)
# sort in dicending order of diff
# Out:
#             actual  prediction       diff
# DATE
# 2007-03-26    78.0   49.744725  28.255275
# 1999-01-02    53.0   25.911898  27.088102
# 1998-03-26    80.0   53.033957  26.966043
# 1985-04-18    84.0   57.071179  26.928821
# 1990-03-12    85.0   58.144310  26.855690
# ...            ...         ...        ...
# 2006-08-20    88.0   88.002937   0.002937
# 2019-03-01    40.0   40.002460   0.002460
# 1992-06-11    76.0   76.001641   0.001641
# 2011-09-16    66.0   66.000831   0.000831
# 2014-03-25    39.0   38.999920   0.000080
#
# [15745 rows x 3 columns]

# %%
pd.Series(rr.coef_, index=predictors)
# Out:
# prcp   -1.234541
# snow   -0.408181
# snwd    0.053086
# tmax    0.447724
# tmin    0.516944
# dtype: float64

# %%
def pct_diff(old, new):
    return (new - old) / old #percentage diff

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"
    weather[label] = weather[col].rolling(horizon).mean() #find the mean of the past n days from any date from a perticular coloumn
    weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
    return weather
    
rolling_horizons = [3, 14]
for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(weather, horizon, col)

# %%
weather
#pct mean percentage diff
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-02-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  \
# DATE
# 1970-01-01  28.0  22.0    31.0             NaN                 NaN
# 1970-01-02  31.0  22.0    38.0             NaN                 NaN
# 1970-01-03  38.0  25.0    31.0       32.333333            0.175258
# 1970-01-04  31.0  23.0    35.0       33.333333           -0.070000
# 1970-01-05  35.0  21.0    36.0       34.666667            0.009615
# ...          ...   ...     ...             ...                 ...
# 2023-02-02  39.0  24.0    35.0       40.666667           -0.040984
# 2023-02-03  35.0  11.0    27.0       37.333333           -0.062500
# 2023-02-04  27.0   4.0    44.0       33.666667           -0.198020
# 2023-02-05  44.0  27.0    44.0       35.333333            0.245283
# 2023-02-06  44.0  27.0    44.0       38.333333            0.147826
#
#             rolling_3_tmin  rolling_3_tmin_pct  rolling_3_prcp  \
# DATE
# 1970-01-01             NaN                 NaN             NaN
# 1970-01-02             NaN                 NaN             NaN
# 1970-01-03       23.000000            0.086957        0.006667
# 1970-01-04       23.333333           -0.014286        0.006667
# 1970-01-05       23.000000           -0.086957        0.006667
# ...                    ...                 ...             ...
# 2023-02-02       27.000000           -0.111111        0.016667
# 2023-02-03       20.333333           -0.459016        0.006667
# 2023-02-04       13.000000           -0.692308        0.000000
# 2023-02-05       14.000000            0.928571        0.000000
# 2023-02-06       19.333333            0.396552        0.000000
#
#             rolling_3_prcp_pct  rolling_14_tmax  rolling_14_tmax_pct  \
# DATE
# 1970-01-01                 NaN              NaN                  NaN
# 1970-01-02                 NaN              NaN                  NaN
# 1970-01-